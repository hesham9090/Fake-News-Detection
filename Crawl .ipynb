# %%
import scrapy

# %%
class BrickSetSpider(scrapy.Spider):
    name = "brickset_spider"
    start_urls = ['https://docs.scrapy.org/en/latest/_static/selectors-sample1.html']
    response.xpath('//title/text()')

    def parse(self, response):
        SET_SELECTOR = '.set'
        for brickset in response.css(SET_SELECTOR):
            
            print(brickset)
           # NAME_SELECTOR = 'h1 ::text'
            #yield {
             #   'name': brickset.css(NAME_SELECTOR).extract_first(),
            #}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-77f86a8b78f9> in <module>
# ----> 1 class BrickSetSpider(scrapy.Spider):
#       2     name = "brickset_spider"
#       3     start_urls = ['https://docs.scrapy.org/en/latest/_static/selectors-sample1.html']
#       4     response.xpath('//title/text()')
#       5
#
# <ipython-input-7-77f86a8b78f9> in BrickSetSpider()
#       2     name = "brickset_spider"
#       3     start_urls = ['https://docs.scrapy.org/en/latest/_static/selectors-sample1.html']
# ----> 4     response.xpath('//title/text()')
#       5
#       6     def parse(self, response):
#
# NameError: name 'response' is not defined

# %%
from scrapy.spiders import CrawlSpider, Rule
from scrapy.linkextractors import LinkExtractor

class ElectronicsSpider(CrawlSpider):
    name = "electronics"
    allowed_domains = ["www.olx.com.pk"]
    start_urls = [
        'https://www.olx.com.pk/computers-accessories/',
        'https://www.olx.com.pk/tv-video-audio/',
        'https://www.olx.com.pk/games-entertainment/'
    ]

    rules = (
        Rule(LinkExtractor(allow=(), restrict_css=('.pageNextPrev',)),
             callback="parse_item",
             follow=True),)

    def parse_item(self, response):
        print('Processing..' + response.url)
        item_links = response.css('.large > .detailsLink::attr(href)').extract()
        for a in item_links:
            yield scrapy.Request(a, callback=self.parse_detail_page)

# %%
# importing the libraries
from bs4 import BeautifulSoup
import requests

url="https://www.politifact.com/truth-o-meter/statements/"

# Make a GET request to fetch the raw HTML content
html_content = requests.get(url).text

# Parse the html content
soup = BeautifulSoup(html_content, "lxml")
print(soup.prettify()) # print the parsed data of html
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="https://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="https://ogp.me/ns#">
#  <head>
#   <title>
#    Our latest fact-checks | PolitiFact
#   </title>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
#   <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="description"/>
#   <meta content="PolitiFact" name="twitter:username"/>
#   <meta content="qAV0CDw3qyhv8XdVwp6m1xDBnW9Q1sRAAynq6kDP7kE" name="google-site-verification"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://static.politifact.com/images/favicon.ico" rel="shortcut icon" type="image/ico"/>
#   <link href="https://static.politifact.com/images/favicon.png" rel="icon" type="image/png"/>
# ...

# %%
{'titles': '<div class="statement__source">\n<a href="/personalities/facebook-posts/">\nFacebook posts\n</a>\n</div>'}

# %%
soup.find_all(lambda tag: tag.name == 'div' and tag.get('class') == ['statement__body'])
# Out:
# [<div class="statement__body">
#  <div class="mugshot">
#  <a href="/personalities/facebook-posts/">
#  <img alt=" Facebook posts" src="https://static.politifact.com/CACHE/images/politifact/mugs/Facebook_icon_1/0d60fb7591f190bacde491772ad28cef.jpg"/>
#  </a>
#  </div>
#  <div class="statement__source">
#  <a href="/personalities/facebook-posts/">
#  Facebook posts
#  </a>
#  </div>
#  <p class="statement__text">
#  <a class="link" href="/facebook-fact-checks/statements/2019/oct/25/facebook-posts/no-british-parliament-didnt-ban-witchcraft-lipstic/">Says that in 1770 "British parliament banned lipstick, saying it had the power to seduce men into marriage, which was classified as witchcraft."</a>
#  </p>
#  <p class="statement__edition">
#  <a href="/facebook-fact-checks">
#  — PolitiFact Facebook fact-checks
#  </a>
#  <span class="article__meta">on Friday, October 25th, 2019</span>
#  </p>
#  </div>, <div class="statement__body">
#  <div class="mugshot">
# ...

# %%
for link in soup.find_all(attrs={'class': 'statement'}):
    for image in link.find_all(attrs={'class': 'meter'}):
        
        print(image)
       # print("img:{}".format(image.get('<a')))
    #print(link)
    #print("Inner Text: {}".format(link.text))
   # print("Title: {}".format(link.get("statement__source")))
   # print("href: {}".format(link.get("href")))
    #print("img:{}".format(image.get("img")))
# Out:
# <div class="meter">
# <a href="/personalities/facebook-posts/statements/byruling/pants-fire/">
# <img alt="Pants on Fire!" src="https://static.politifact.com/CACHE/images/rulings/tom-pantsonfire/45eadbc582a26dc79f69e11132ebeb9d.jpg"/>
# </a>
# <p class="quote">Maybe it’s witchcraft, maybe it’s Maybelline</p>
# </div>
# <div class="meter">
# <a href="/personalities/viral-image/statements/byruling/false/">
# <img alt="False" src="https://static.politifact.com/CACHE/images/rulings/tom-false/e5c0d30b7228205f896c99d3216f498f.jpg"/>
# </a>
# <p class="quote">Some advice? This quote is apocryphal</p>
# </div>
# <div class="meter">
# <a href="/personalities/glenn-kage/statements/byruling/half-true/">
# <img alt="Half-True" src="https://static.politifact.com/CACHE/images/rulings/tom-halftrue/478128fb00ada265925ac70641778737.jpg"/>
# </a>
# <p class="quote">Not the case recently</p>
# </div>
# <div class="meter">
# <a href="/personalities/chain-email/statements/byruling/pants-fire/">
# ...

# %%
for link in soup.find_all(attrs={'class': 'statement'}):
    #print(link)
    for image in link.find_all(attrs={'class': 'meter'}):
        #print(image.get("div"))
        print("img:{}".format(image.img))
        #print("href: {}".format(image.get("</a>")))
    #print(link)
       # print("Inner Text: {}".format(image.text))
   # print("href: {}".format(link.get("href")))
    #print("img:{}".format(image.get("img")))
# Out:
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None
# img:None

# %%
print(soup.section)
# Out:
# <section class="ldrbd" id="ldr">
# <div id="ad-topleaderboard">
# <script>
#      AdBridg.cmd.push(function() {
#        var mapping = AdBridg.sizeMapping().
#            // Accepts common mobile banner formats
#             addSize([320, 400], [[320, 50]]).
#            // Horizontal Phone
#             addSize([667, 375], [[320,50]]).
#            // Vertical tablet
#             addSize([600, 900], [[320,50]]).
#            // Landscape tablet
#             addSize([768, 200], [[728, 90]]).
#            // Desktop
#             addSize([1000, 200], [[728, 90]]).build();
#        var slot = AdBridg.defineSlot('/25722649/Politifact/Politifact_TopLeaderboard', [320, 50], 'ad-topleaderboard')
#                          .defineSizeMapping(mapping);
#        window.gptAdSlots.push(slot);
#        AdBridg.useSizeMapping(slot, mapping);
#        AdBridg.display('ad-topleaderboard');
#        AdBridg.serve();
#      });
#    </script>
# </div>
# </section>

# %%
import scrapy


class ZapposMenShoesSpider(scrapy.Spider):
    name = "zappos_p"
    start_urls = ['https://www.zappos.com/men-running-shoes']
    allowed_domains = ['www.zappos.com']


    def parse(self, response):
        for product in response.css("article"):
            print("ddddddddd")
            #yield {
             #   "name": product.css("p[itemprop='name']::text").extract_first(),
              #  "by": product.css("p[itemprop='brand'] span[itemprop='name']::text").extract_first(),
               # "price": product.css("p span::text").extract()[1],
                #"stars": product.css(
                 #   "p span[itemprop='aggregateRating']::attr('data-star-rating')"
                #).extract_first(),
                #"img-url": product.css(
                 #   "div span img::attr('src')").extract_first()
            #}


      #  next_url_path = response.css(
        #     "a[rel='next']::attr('href')").extract_first()
        #if next_url_path:
            #   yield scrapy.Request(
            #   response.urljoin(next_url_path),
            #   callback=self.parse
            #)
